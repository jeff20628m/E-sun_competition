# %%
import tensorflow as tf
import keras
from tensorflow.keras.layers import Input, Conv2D, Lambda, Dense, Flatten, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import binary_crossentropy
import numpy.random as rng
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import shuffle


def solve_cudnn_error():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            # Currently, memory growth needs to be the same across GPUs
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            logical_gpus = tf.config.experimental.list_logical_devices('GPU')
            print(len(gpus), "Physical GPUs,", len(logical_gpus),
                  "Logical GPUs")
        except RuntimeError as e:
            # Memory growth must be set before GPUs have been initialized
            print(e)


solve_cudnn_error()

# %matplotlib inline
# def W_init(shape, dtype=None):
#     """Initialize weights as in paper"""
#     values = rng.normal(loc=0, scale=1e-2, size=shape)
#     return K.variable(values, dtype=dtype)

# #//TODO: figure out how to initialize layer biases in keras.
# def b_init(shape, dtype=None):
#     """Initialize bias as in paper"""
#     values = rng.normal(loc=0.5, scale=1e-2, size=shape)
#     return K.variable(values, dtype=dtype)

input_shape = (96, 96, 3)
left_input = Input(input_shape)
right_input = Input(input_shape)
#build convnet to use in each siamese 'leg'
convnet = Sequential()
convnet.add(
    Conv2D(64, (10, 10),
           activation='relu',
           input_shape=input_shape,
           kernel_regularizer=l2(2e-4))),
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128, (7, 7), activation='relu',
                   kernel_regularizer=l2(2e-4))),
convnet.add(MaxPooling2D())
convnet.add(Conv2D(128, (4, 4), activation='relu',
                   kernel_regularizer=l2(2e-4))),
convnet.add(MaxPooling2D())
convnet.add(Conv2D(256, (4, 4), activation='relu',
                   kernel_regularizer=l2(2e-4))),
convnet.add(Flatten())
convnet.add(Dense(4096, activation="sigmoid", kernel_regularizer=l2(1e-3)))

#call the convnet Sequential model on each of the input tensors so params will be shared
encoded_l = convnet(left_input)
encoded_r = convnet(right_input)
#layer to merge two encoded inputs with the l1 distance between them
L1_layer = Lambda(lambda tensors: K.abs(tensors[0] - tensors[1]))
#call this layer on list of two input tensors.
L1_distance = L1_layer([encoded_l, encoded_r])
prediction = Dense(1, activation='sigmoid')(L1_distance)
siamese_net = Model(inputs=[left_input, right_input], outputs=prediction)

optimizer = Adam(0.001)
#//TODO: get layerwise learning rates and momentum annealing scheme described in paperworking
siamese_net.compile(loss="binary_crossentropy", optimizer=optimizer)

siamese_net.count_params()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 17993025

# %%
convnet.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 87, 87, 64)        19264
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 43, 43, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 37, 37, 128)       401536
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 15, 15, 128)       262272
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 4, 4, 256)         524544
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# =================================================================
# Total params: 17,988,928
# Trainable params: 17,988,928
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Data
# The data is pickled as an N_classes x n_examples x width x height array, and there is an accompanyng dictionary to specify which indexes belong to which languages.

# %%
PATH = "../../../data_set/模型訓練資料/save/"  #CHANGE THIS - path where the pickled data is stored

with open(os.path.join(PATH, "x_train.pickle"), "rb") as f:
    (X, c, l) = pickle.load(f)
    
with open(os.path.join(PATH, "x_val.pickle"), "rb") as f:
    (Xval, cval, lval) = pickle.load(f)

print("training alphabets")
print(c)
# Out:
# training alphabets
# {0: ['丁'], 1: ['三'], 2: ['上'], 3: ['不'], 4: ['世'], 5: ['丞'], 6: ['中'], 7: ['主'], 8: ['久'], 9: ['之'], 10: ['事'], 11: ['于'], 12: ['五'], 13: ['亞'], 14: ['交'], 15: ['亨'], 16: ['京'], 17: ['亮'], 18: ['人'], 19: ['仁'], 20: ['介'], 21: ['仕'], 22: ['仙'], 23: ['代'], 24: ['仲'], 25: ['任'], 26: ['份'], 27: ['企'], 28: ['伊'], 29: ['伍'], 30: ['伯'], 31: ['伶'], 32: ['位'], 33: ['佑'], 34: ['何'], 35: ['余'], 36: ['作'], 37: ['佩'], 38: ['佳'], 39: ['來'], 40: ['侑'], 41: ['侯'], 42: ['俊'], 43: ['保'], 44: ['信'], 45: ['修'], 46: ['倉'], 47: ['倫'], 48: ['偉'], 49: ['健'], 50: ['傅'], 51: ['傑'], 52: ['備'], 53: ['傳'], 54: ['僑'], 55: ['儀'], 56: ['億'], 57: ['儒'], 58: ['優'], 59: ['允'], 60: ['元'], 61: ['兆'], 62: ['先'], 63: ['光'], 64: ['克'], 65: ['兒'], 66: ['內'], 67: ['全'], 68: ['公'], 69: ['其'], 70: ['具'], 71: ['典'], 72: ['冠'], 73: ['冷'], 74: ['凌'], 75: ['凍'], 76: ['凱'], 77: ['分'], 78: ['利'], 79: ['刷'], 80: ['券'], 81: ['創'], 82: ['劉'], 83: ['力'], 84: ['加'], 85: ['助'], 86: ['勁'], 87: ['勇'], 88: ['動'], 89: ['務'], 90: ['勝'], 91: ['勤'], 92: ['勳'], 93: ['包'], 94: ['化'], 95: ['北'], 96: ['匠'], 97: ['匯'], 98: ['區'], 99: ['千'], 100: ['升'], 101: ['卉'], 102: ['卓'], 103: ['協'], 104: ['南'], 105: ['博'], 106: ['印'], 107: ['卿'], 108: ['厚'], 109: ['原'], 110: ['友'], 111: ['古'], 112: ['可'], 113: ['台'], 114: ['司'], 115: ['合'], 116: ['吉'], 117: ['同'], 118: ['名'], 119: ['君'], 120: ['吟'], 121: ['吳'], 122: ['呂'], 123: ['呈'], 124: ['告'], 125: ['周'], 126: ['和'], 127: ['品'], 128: ['員'], 129: ['哲'], 130: ['唐'], 131: ['商'], 132: ['問'], 133: ['啟'], 134: ['善'], 135: ['喜'], 136: ['喬'], 137: ['嘉'], 138: ['器'], 139: ['國'], 140: ['園'], 141: ['圓'], 142: ['圖'], 143: ['團'], 144: ['土'], 145: ['地'], 146: ['坊'], 147: ['坤'], 148: ['城'], 149: ['培'], 150: ['基'], 151: ['堂'], 152: ['堅'], 153: ['堡'], 154: ['堯'], 155: ['報'], 156: ['場'], 157: ['塑'], 158: ['境'], 159: ['士'], 160: ['壽'], 161: ['多'], 162: ['大'], 163: ['天'], 164: ['太'], 165: ['央'], 166: ['奇'], 167: ['奕'], 168: ['女'], 169: ['好'], 170: ['如'], 171: ['妤'], 172: ['妮'], 173: ['妹'], 174: ['委'], 175: ['姚'], 176: ['姜'], 177: ['姿'], 178: ['威'], 179: ['娟'], 180: ['娥'], 181: ['婉'], 182: ['婕'], 183: ['婷'], 184: ['媒'], 185: ['媛'], 186: ['嬌'], 187: ['子'], 188: ['孟'], 189: ['孫'], 190: ['學'], 191: ['宇'], 192: ['守'], 193: ['安'], 194: ['宋'], 195: ['宏'], 196: ['宗'], 197: ['定'], 198: ['宜'], 199: ['客'], 200: ['宣'], 201: ['室'], 202: ['宥'], 203: ['家'], 204: ['宸'], 205: ['容'], 206: ['密'], 207: ['富'], 208: ['寓'], 209: ['實'], 210: ['寧'], 211: ['寬'], 212: ['寶'], 213: ['專'], 214: ['小'], 215: ['尚'], 216: ['局'], 217: ['居'], 218: ['屋'], 219: ['展'], 220: ['屬'], 221: ['山'], 222: ['岳'], 223: ['峰'], 224: ['峻'], 225: ['崇'], 226: ['川'], 227: ['工'], 228: ['巧'], 229: ['巨'], 230: ['巫'], 231: ['市'], 232: ['希'], 233: ['帝'], 234: ['師'], 235: ['常'], 236: ['平'], 237: ['年'], 238: ['幸'], 239: ['幼'], 240: ['店'], 241: ['庭'], 242: ['康'], 243: ['廈'], 244: ['廖'], 245: ['廠'], 246: ['廣'], 247: ['廷'], 248: ['建'], 249: ['弘'], 250: ['張'], 251: ['強'], 252: ['彥'], 253: ['彩'], 254: ['彬'], 255: ['彭'], 256: ['彰'], 257: ['影'], 258: ['律'], 259: ['徐'], 260: ['得'], 261: ['御'], 262: ['復'], 263: ['德'], 264: ['心'], 265: ['志'], 266: ['忠'], 267: ['念'], 268: ['思'], 269: ['怡'], 270: ['恆'], 271: ['恩'], 272: ['悅'], 273: ['惠'], 274: ['意'], 275: ['愛'], 276: ['愷'], 277: ['慈'], 278: ['慧'], 279: ['慶'], 280: ['憲'], 281: ['憶'], 282: ['應'], 283: ['成'], 284: ['戴'], 285: ['戶'], 286: ['房'], 287: ['所'], 288: ['扶'], 289: ['承'], 290: ['技'], 291: ['投'], 292: ['拉'], 293: ['拓'], 294: ['振'], 295: ['捷'], 296: ['揚'], 297: ['政'], 298: ['敏'], 299: ['教'], 300: ['敦'], 301: ['敬'], 302: ['整'], 303: ['數'], 304: ['文'], 305: ['斌'], 306: ['料'], 307: ['斯'], 308: ['新'], 309: ['方'], 310: ['施'], 311: ['旅'], 312: ['日'], 313: ['旭'], 314: ['旺'], 315: ['旻'], 316: ['昆'], 317: ['昇'], 318: ['昌'], 319: ['明'], 320: ['易'], 321: ['昕'], 322: ['星'], 323: ['映'], 324: ['春'], 325: ['昭'], 326: ['昱'], 327: ['昶'], 328: ['時'], 329: ['晉'], 330: ['晟'], 331: ['晨'], 332: ['普'], 333: ['景'], 334: ['晴'], 335: ['晶'], 336: ['智'], 337: ['暉'], 338: ['暘'], 339: ['曉'], 340: ['曜'], 341: ['書'], 342:  ...

# %%
class Siamese_Loader:
    """For loading batches and testing tasks to a siamese net"""
    def __init__(self, path, data_subsets=["train", "val"]):
        self.data = {}
        self.label = {}
        self.categories = {}
        self.lang_dict = {}
        self.info = {}
        self.n_class = 0
        # loading the data
        for name in data_subsets:
            file_path = os.path.join(path, "x_" + name + ".pickle")
            print("loading data from {}".format(file_path))
            with open(file_path, "rb") as f:
                (X, c, l) = pickle.load(f)
                self.data[name] = X
                self.categories[name] = c
                self.lang_dict[name] = l
        # loading the label
        for name in data_subsets:
            file_path = os.path.join(path, "y_" + name + ".pickle")
            print("loading data from {}".format(file_path))
            with open(file_path, "rb") as f:
                y = pickle.load(f)
                self.label[name] = y

    def get_batch(self, batch_size, s="train"):
        """Create batch of n pairs, half same class, half different class"""
        X = self.data[s]
        y = self.label[s]
        l = self.lang_dict[s]
        c = self.categories[s]
        all_samples, w, h, chanel = X.shape
        n_classes = len(c)
        #randomly sample several classes to use in the batch
        categories_temp = rng.choice(n_classes,
                                     size=(batch_size, ),
                                     replace=False)
        #initialize 2 empty arrays for the input image batch

        #pairs=[np.zeros((batch_size, w, h,chanel)) for i in range(2)]
        pairs0 = []
        pairs1 = []
        #initialize vector for the targets, and make one half of it '1's, so 2nd half of batch has same class
        targets = np.zeros((batch_size, ))
        targets[batch_size // 2:] = 1
        for i in range(batch_size):
            category = categories_temp[i]
            # find the num of examples of the class
            idx_1 = rng.randint(l[c[category][0]][0], l[c[category][0]][1])
            pairs0.append(X[idx_1])
            #pick images of same class for 1st half, different for 2nd
            if i >= batch_size // 2:
                category_2 = category
            else:
                #add a random number to the category modulo n classes to ensure 2nd image has
                # ..different category
                category_2 = rng.randint(n_classes)

            idx_2 = rng.randint(l[c[category_2][0]][0], l[c[category_2][0]][1])
            pairs1.append(X[idx_2])

        pairs0 = np.stack(pairs0)
        pairs1 = np.stack(pairs1)
        pairs = [pairs0, pairs1]
        return pairs, targets

    def generate(self, batch_size, s="train"):
        """a generator for batches, so model.fit_generator can be used. """
        while True:
            pairs, targets = self.get_batch(batch_size, s)
            yield (pairs, targets)

    def make_oneshot_task(self, N, s="val", words=None):
        """Create pairs of test image, support set for testing N way one-shot learning. """
        X = self.data[s]
        y = self.label[s]
        l = self.lang_dict[s]
        c = self.categories[s]
        all_samples, w, h, chanel = X.shape

        if s == 'val':
            n_classes_low = list(loader.categories['val'].keys())[0]
            n_classes_high = list(loader.categories['val'].keys())[-1]
        else:
            n_classes = len(c)

        #indices = rng.randint(0,n_examples,size=(N,))
        if words is not None:
            low, high = l[words]
            if N > high - low:
                raise ValueError(
                    "This language ({}) has less than {} letters".format(
                        words, N))
            categories = rng.choice(range(low, high), size=(N, ))

        else:  #if no language specified just pick a bunch of random letters
            if s == 'val':
                categories = rng.choice(range(n_classes_low, n_classes_high),
                                        size=(N, ),
                                        replace=False)
            else:
                categories = rng.choice(range(n_classes),
                                        size=(N, ),
                                        replace=False)
        true_category = categories[0]
        ex1 = rng.randint(l[c[true_category][0]][0], l[c[true_category][0]][1])
        ex2 = rng.randint(l[c[true_category][0]][0], l[c[true_category][0]][1])
        test_image = np.asarray([X[ex1]] * N).reshape(N, w, h, 3)

        # build the support set
        support_set = []
        for category in categories:
            idx = rng.randint(l[c[category][0]][0], l[c[category][0]][1])
            support_set.append(X[idx])
        support_set = np.stack(support_set)
        support_set[0] = X[ex2]
        #        support_set = support_set.reshape(N, w, h,3)
        targets = np.zeros((N, ))
        targets[0] = 1
        targets, test_image, support_set = shuffle(targets, test_image,
                                                   support_set)
        pairs = [test_image, support_set]

        return pairs, targets

    def test_oneshot(self, model, N, k, s="val", verbose=0):
        """Test average N way oneshot learning accuracy of a siamese neural net over k one-shot tasks"""
        n_correct = 0
        if verbose:
            print(
                "Evaluating model on {} random {} way one-shot learning tasks ..."
                .format(k, N))
        for i in range(k):
            inputs, targets = self.make_oneshot_task(N, s)
            probs = model.predict(inputs)
            if np.argmax(probs) == np.argmax(targets):
                n_correct += 1
        percent_correct = (100.0 * n_correct / k)
        if verbose:
            print("Got an average of {}% {} way one-shot learning accuracy".
                  format(percent_correct, N))
        return percent_correct

    def train(self, model, epochs, verbosity):
        model.fit_generator(self.generate(batch_size), )


#Instantiate the class
loader = Siamese_Loader(PATH)
# Out:
# loading data from ../../../data_set/模型訓練資料/save/x_train.pickle
# loading data from ../../../data_set/模型訓練資料/save/x_val.pickle
# loading data from ../../../data_set/模型訓練資料/save/y_train.pickle
# loading data from ../../../data_set/模型訓練資料/save/y_val.pickle

# %%
# i just concat the images into same shape in the data loader
def concat_images(X):
    """Concatenates a bunch of images into a big matrix for plotting purposes."""
    N, h, w, chanel = X.shape
    X = X.reshape(N, h, w, chanel)
    n = int(np.ceil(np.sqrt(N)))
    img = np.zeros((n * w, n * h, 3))
    x = 0
    y = 0
    for example in range(N):
        img[x * w:(x + 1) * w, y * h:(y + 1) * h] = X[example]
        y += 1
        if y >= n:
            y = 0
            x += 1
    return img


def plot_oneshot_task(pairs):
    """Takes a one-shot task given to a siamese net and  """
    fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 15))
    ax1.matshow(pairs[0][0], cmap='gray')
    img = concat_images(pairs[1])
    ax1.get_yaxis().set_visible(False)
    ax1.get_xaxis().set_visible(False)
    ax2.matshow(img.astype('uint8'), cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()


#example of a one-shot learning task
pairs, targets = loader.make_oneshot_task(25, "train")
plot_oneshot_task(pairs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-d87ba2f4b9f5> in <module>
#      31
#      32 #example of a one-shot learning task
# ---> 33 pairs, targets = loader.make_oneshot_task(25, "train")
#      34 plot_oneshot_task(pairs)
#
# <ipython-input-19-d35560cd4373> in make_oneshot_task(self, N, s, words)
#      78         l = self.lang_dict[s]
#      79         c = self.categories[s]
# ---> 80         all_samples, w, h, chanel = X.shape
#      81
#      82         if s == 'val':
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
#Training loop
print("!")
evaluate_every = 1  # interval for evaluating on one-shot tasks
loss_every = 50  # interval for printing loss (iterations)
batch_size = 32
n_iter = 1000
N_way = 12  # how many classes for testing one-shot tasks>
n_val = 20  #how mahy one-shot tasks to validate on?
best = -1
weights_path = os.path.join(PATH, "weights")
print("training")
for i in range(1, n_iter):
    (inputs, targets) = loader.get_batch(batch_size)
    loss = siamese_net.train_on_batch(inputs, targets)
    print(loss)
    if i % evaluate_every == 0:
        print("evaluating")
        val_acc = loader.test_oneshot(siamese_net, N_way, n_val, verbose=True)
        if val_acc >= best:
            print("saving")
            siamese_net.save(weights_path)
            best = val_acc

    if i % loss_every == 0:
        print("iteration {}, training loss: {:.2f},".format(i, loss))
# Out:
# !
# training
# 1.1050317287445068
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.1033909320831299
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0992050170898438
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0969314575195312
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0961569547653198
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0930227041244507
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0914300680160522
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0884534120559692
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0862517356872559
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0849745273590088
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0831283330917358
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0806167125701904
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0781652927398682
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0753792524337769
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0742841958999634
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0691630840301514
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0700575113296509
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0673428773880005
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.064851999282837
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0651991367340088
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0607255697250366
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.059674620628357
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0573195219039917
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0553083419799805
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.053586483001709
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.05266535282135
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.050028920173645
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0479087829589844
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.045522928237915
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0451148748397827
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0430296659469604
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0420066118240356
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0404750108718872
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0368695259094238
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0357203483581543
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.034866452217102
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0325853824615479
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0301687717437744
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0284109115600586
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0273669958114624
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0261121988296509
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0244641304016113
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0234684944152832
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.022635579109192
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0185054540634155
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0125811100006104
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0170402526855469
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0152826309204102
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.010823130607605
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0132888555526733
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# iteration 50, training loss: 1.01,
# 1.01220703125
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.0094196796417236
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 1.007145643234253
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 25.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 1.0064805746078491
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0063064098358154
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 1.0014013051986694
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0040477514266968
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0020545721054077
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 1.0015456676483154
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 1.0002200603485107
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 1.0007058382034302
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9978055953979492
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9966753125190735
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9951980710029602
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9944161176681519
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9931838512420654
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9917855262756348
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9907568693161011
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9893720149993896
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9884482026100159
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9868248105049133
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.984969973564148
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9845961332321167
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.983565092086792
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9825565814971924
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9825749397277832
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9795825481414795
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9791291356086731
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9774570465087891
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9780542850494385
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9761723279953003
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9757670760154724
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9753797650337219
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9732577800750732
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9723300337791443
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9702272415161133
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9706432819366455
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9693639278411865
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9679238796234131
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9680808782577515
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9660478830337524
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9610116481781006
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9651683568954468
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9638088941574097
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9634793996810913
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9625684022903442
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.961856484413147
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.961483895778656
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9611023664474487
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9589142203330994
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# iteration 100, training loss: 0.96,
# 0.9587445259094238
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9579210877418518
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9571577310562134
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9563174843788147
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9559438824653625
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9554436802864075
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9542798399925232
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9536263942718506
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9529157280921936
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9525173902511597
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.952842116355896
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9506935477256775
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.949845552444458
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9493616819381714
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9487119317054749
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9480096101760864
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9470632076263428
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9462683200836182
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9458823204040527
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9445433020591736
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9443800449371338
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9438304901123047
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9426809549331665
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9422696828842163
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9414269924163818
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9409050941467285
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9399673938751221
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9398298859596252
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.939258873462677
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9389088153839111
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9369537830352783
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9366030693054199
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9358658194541931
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9357382655143738
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9350714087486267
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9341486692428589
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9334061145782471
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9330765008926392
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9324912428855896
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9323410391807556
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9315192103385925
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9313618540763855
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9305444955825806
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9303611516952515
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9294964671134949
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9287819266319275
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9284248352050781
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9283878803253174
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9280611276626587
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9268414974212646
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# iteration 150, training loss: 0.93,
# 0.9261137843132019
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9255121350288391
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9262046813964844
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.925116777420044
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9239170551300049
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9239526391029358
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9229273796081543
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9225629568099976
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9230824112892151
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9222960472106934
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9220266342163086
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9213147759437561
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9210620522499084
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9204613566398621
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9202039241790771
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9199352264404297
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9198833703994751
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9190206527709961
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9186707139015198
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9175485372543335
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9182847142219543
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9172120094299316
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 25.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 0.9160293340682983
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.917213499546051
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9138651490211487
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9155486822128296
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9157012104988098
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.915529727935791
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9148913025856018
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9152417182922363
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9159217476844788
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9135611653327942
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9181495308876038
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9130520820617676
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9126641750335693
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9125348925590515
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9119235277175903
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.912432074546814
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9116401672363281
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9114155173301697
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9109320640563965
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9116086363792419
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9107338190078735
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9107497334480286
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.909342885017395
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9096230268478394
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.909809410572052
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9089794754981995
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.909286618232727
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9098566770553589
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# iteration 200, training loss: 0.91,
# 0.9090114831924438
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9082735180854797
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9084652662277222
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9075303077697754
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9066756963729858
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9080579280853271
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9101051092147827
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.906958818435669
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9058074355125427
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9070212244987488
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9060513973236084
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9062048196792603
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 25.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 0.9076188206672668
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.905669629573822
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9083678722381592
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.90702223777771
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9084774851799011
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.906404435634613
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9053610563278198
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9063736796379089
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9052795171737671
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9052167534828186
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.905529797077179
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9049268364906311
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9051929712295532
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9060432314872742
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.904132068157196
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9040019512176514
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9055142998695374
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.904473066329956
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9052286148071289
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9057362079620361
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9034602642059326
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9050039649009705
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9059630036354065
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9057820439338684
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9053893089294434
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.904066801071167
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9046454429626465
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9052727222442627
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9048471450805664
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9037017822265625
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9044771194458008
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9050072431564331
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9045571088790894
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9041232466697693
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9046236276626587
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9048957228660583
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9039341807365417
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 30.0% 12 way one-shot learning accuracy
# saving
# INFO:tensorflow:Assets written to: ../../../data_set/模型訓練資料/save/weights\assets
# 0.9016355872154236
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# iteration 250, training loss: 0.90,
# 0.9052245616912842
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9031774997711182
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9042287468910217
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9033247232437134
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9033912420272827
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9034017324447632
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.902842104434967
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9026815891265869
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.904204249382019
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9029557704925537
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9029726982116699
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9022554159164429
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9013612270355225
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9010480642318726
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9018364548683167
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9004052877426147
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9007234573364258
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9027297496795654
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8998333215713501
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9013235569000244
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9004402160644531
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.8995698690414429
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8996706604957581
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9004613161087036
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9019408226013184
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8985889554023743
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8984703421592712
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9006756544113159
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.8997488617897034
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8995492458343506
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8981308937072754
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.8990930318832397
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8981397151947021
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.8961337804794312
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8995208740234375
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8987756967544556
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.8993238806724548
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.8978738784790039
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8981595635414124
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8976640701293945
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9003810882568359
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.898978590965271
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8975088000297546
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8967893123626709
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.8983426690101624
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.8991329669952393
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9015886187553406
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8965069651603699
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8972600698471069
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8980163335800171
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# iteration 300, training loss: 0.90,
# 0.8956117033958435
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8976130485534668
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.8981170654296875
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.897264838218689
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.8963252305984497
# evaluating
# ...
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9112579822540283
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9117616415023804
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9123147130012512
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9128183126449585
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9134383797645569
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9139707684516907
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.914463996887207
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9149101972579956
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9152317643165588
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9164566993713379
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9160715937614441
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9169970154762268
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9158397912979126
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9180984497070312
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9169057011604309
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9170559644699097
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.917233943939209
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9167633652687073
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9184424877166748
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9176490306854248
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 25.0% 12 way one-shot learning accuracy
# 0.9177470207214355
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9178363680839539
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9179057478904724
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9179518222808838
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9157425165176392
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9179743528366089
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9176170229911804
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9177930951118469
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9179614782333374
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9174950122833252
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9177415370941162
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9176592826843262
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# iteration 550, training loss: 0.92,
# 0.9175658822059631
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9174603223800659
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9173450469970703
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9172210097312927
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9170873165130615
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9163406491279602
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9167895317077637
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.916625440120697
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 25.0% 12 way one-shot learning accuracy
# 0.9160640239715576
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9169334769248962
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9160764217376709
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9158764481544495
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9156690835952759
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9154548645019531
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9152345061302185
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9145405292510986
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9148542881011963
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9145485758781433
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9143232703208923
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9141005277633667
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9138787984848022
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.913596510887146
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9134368300437927
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9136613607406616
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9130061864852905
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9130796194076538
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9129990339279175
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9123910665512085
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9121977090835571
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9120132327079773
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9118679165840149
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9116578102111816
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9114825129508972
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.911306619644165
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9111286997795105
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9109506607055664
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.910771906375885
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9105965495109558
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9104217290878296
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9102470278739929
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# 0.9100807309150696
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9101418256759644
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9097382426261902
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9095728397369385
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9094058275222778
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 5.0% 12 way one-shot learning accuracy
# 0.9092363119125366
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 20.0% 12 way one-shot learning accuracy
# 0.9090538024902344
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9088982939720154
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9087384343147278
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.908581554889679
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# iteration 600, training loss: 0.91,
# 0.9084251523017883
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9082673788070679
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 10.0% 12 way one-shot learning accuracy
# 0.9081067442893982
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 0.0% 12 way one-shot learning accuracy
# 0.9079424142837524
# evaluating
# Evaluating model on 20 random 12 way one-shot learning tasks ...
# Got an average of 15.0% 12 way one-shot learning accuracy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-9e79cb3271cc> in <module>
#      12 for i in range(1, n_iter):
#      13     (inputs, targets) = loader.get_batch(batch_size)
# ---> 14     loss = siamese_net.train_on_batch(inputs, targets)
#      15     print(loss)
#      16     if i % evaluate_every == 0:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1728
#    1729     if reset_metrics:
# -> 1730       self.reset_metrics()
#    1731     logs = tf_utils.to_numpy_or_python_type(logs)
#    1732     if return_dict:
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in reset_metrics(self)
#    1667     """
#    1668     for m in self.metrics:
# -> 1669       m.reset_states()
#    1670
#    1671   def train_on_batch(self,
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\metrics.py in reset_states(self)
#     251     when a metric is evaluated during training.
#     252     """
# --> 253     K.batch_set_value([(v, 0) for v in self.variables])
#     254
#     255   @abc.abstractmethod
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in batch_set_value(tuples)
#    3704   if ops.executing_eagerly_outside_functions():
#    3705     for x, value in tuples:
# -> 3706       x.assign(np.asarray(value, dtype=dtype(x)))
#    3707   else:
#    3708     with get_graph().as_default():
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     891             (tensor_name, self._shape, value_tensor.shape))
#     892       assign_op = gen_resource_variable_ops.assign_variable_op(
# --> 893           self.handle, value_tensor, name=name)
#     894       if read_value:
#     895         return self._lazy_read(assign_op)
#
# ~\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     139     try:
#     140       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# --> 141         _ctx, "AssignVariableOp", name, resource, value)
#     142       return _result
#     143     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
def nearest_neighbour_correct(pairs, targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0


def test_nn_accuracy(N_ways, n_trials, loader):
    """Returns accuracy of one shot """
    print(
        "Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ..."
        .format(n_trials, N_ways))

    n_right = 0

    for i in range(n_trials):
        pairs, targets = loader.make_oneshot_task(N_ways, "val")
        correct = nearest_neighbour_correct(pairs, targets)
        n_right += correct
    return 100.0 * n_right / n_trials


ways = np.arange(1, 30, 5)
resume = False
val_accs, train_accs, nn_accs = [], [], []
trials = 5
for N in ways:
    val_accs.append(
        loader.test_oneshot(siamese_net, N, trials, "val", verbose=True))
    train_accs.append(
        loader.test_oneshot(siamese_net, N, trials, "train", verbose=True))
    nn_accs.append(test_nn_accuracy(N, trials, loader))

#plot the accuracy vs num categories for each
plt.plot(ways, val_accs, "m")
plt.plot(ways, train_accs, "y")
plt.plot(ways, nn_accs, "c")

plt.plot(ways, 100.0 / ways, "r")
plt.show()
# Out:
# Evaluating model on 5 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating model on 5 random 1 way one-shot learning tasks ...
# Got an average of 100.0% 1 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 1 way one-shot learning tasks ...
# Evaluating model on 5 random 6 way one-shot learning tasks ...
# C:\Users\USER\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:87: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# Got an average of 40.0% 6 way one-shot learning accuracy
# Evaluating model on 5 random 6 way one-shot learning tasks ...
# Got an average of 20.0% 6 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 6 way one-shot learning tasks ...
# Evaluating model on 5 random 11 way one-shot learning tasks ...
# Got an average of 20.0% 11 way one-shot learning accuracy
# Evaluating model on 5 random 11 way one-shot learning tasks ...
# Got an average of 0.0% 11 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 11 way one-shot learning tasks ...
# Evaluating model on 5 random 16 way one-shot learning tasks ...
# Got an average of 0.0% 16 way one-shot learning accuracy
# Evaluating model on 5 random 16 way one-shot learning tasks ...
# Got an average of 0.0% 16 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 16 way one-shot learning tasks ...
# Evaluating model on 5 random 21 way one-shot learning tasks ...
# Got an average of 0.0% 21 way one-shot learning accuracy
# Evaluating model on 5 random 21 way one-shot learning tasks ...
# Got an average of 0.0% 21 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 21 way one-shot learning tasks ...
# Evaluating model on 5 random 26 way one-shot learning tasks ...
# Got an average of 0.0% 26 way one-shot learning accuracy
# Evaluating model on 5 random 26 way one-shot learning tasks ...
# Got an average of 0.0% 26 way one-shot learning accuracy
# Evaluating nearest neighbour on 5 unique 26 way one-shot learning tasks ...

# %%
fig, ax = plt.subplots(1)
ax.plot(ways, val_accs, "m", label="Siamese(val set)")
ax.plot(ways, train_accs, "y", label="Siamese(train set)")
plt.plot(ways, nn_accs, label="Nearest neighbour")

ax.plot(ways, 100.0 / ways, "g", label="Random guessing")
plt.xlabel("Number of possible classes in one-shot tasks")
plt.ylabel("% Accuracy")
plt.title("Omiglot One-Shot Learning Performance of a Siamese Network")
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
inputs, targets = loader.make_oneshot_task(20, "val")
plt.show()

print(inputs[0].shape)
plot_oneshot_task(inputs)
p = siamese_net.predict(inputs)
print(p)
# Out:
# (20, 96, 96, 3)
# [[0.48841012]
#  [0.49144793]
#  [0.48657164]
#  [0.49417728]
#  [0.500797  ]
#  [0.49543148]
#  [0.48898146]
#  [0.48984876]
#  [0.49218655]
#  [0.4909012 ]
#  [0.49097475]
#  [0.48768175]
#  [0.4869906 ]
#  [0.497732  ]
#  [0.49303824]
#  [0.4924707 ]
#  [0.48951557]
#  [0.489018  ]
#  [0.49201894]
#  [0.49039152]]

# %%
np.argmax(p)
# Out:
# 6
